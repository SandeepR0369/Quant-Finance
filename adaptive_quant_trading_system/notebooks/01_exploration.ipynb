# %% [markdown]
# # Exploration Notebook
#
# This notebook demonstrates loading saved outputs from the example backtest.

# %%
import pandas as pd
from pathlib import Path

out = Path('../reports/output')
print(out)
